# %% [markdown]
# import

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
df = pd.read_csv("data_9_1.csv")

# %%
df
# Out:
#         x1     x2
# 0    10.28   8.92
# 1    -2.62   3.98
# 2     9.16  10.11
# 3    -4.32  10.84
# 4     0.20  10.70
# ..     ...    ...
# 195  10.90   8.57
# 196  -3.85   6.00
# 197  10.79   9.95
# 198  10.88  10.95
# 199   3.97  -5.42
#
# [200 rows x 2 columns]

# %%
# Clustering
from sklearn.cluster import KMeans

data = df.to_numpy()
model = KMeans(n_clusters=5)
model.fit(data)
model.labels_
# Out:
# array([1, 0, 4, 3, 3, 4, 2, 3, 1, 2, 0, 3, 2, 0, 4, 1, 3, 1, 2, 2, 0, 4,
#        3, 3, 3, 1, 4, 0, 0, 2, 4, 3, 2, 4, 3, 0, 2, 1, 1, 0, 2, 1, 1, 0,
#        4, 4, 3, 1, 2, 2, 3, 3, 4, 4, 4, 2, 4, 0, 0, 0, 2, 2, 4, 2, 0, 4,
#        1, 0, 3, 0, 3, 3, 1, 0, 0, 3, 2, 1, 3, 3, 4, 3, 4, 4, 1, 1, 2, 2,
#        0, 2, 0, 3, 2, 1, 3, 1, 2, 3, 3, 1, 4, 4, 2, 4, 2, 1, 2, 0, 0, 2,
#        0, 1, 4, 4, 2, 3, 4, 4, 4, 1, 1, 4, 3, 3, 0, 0, 0, 3, 3, 2, 2, 0,
#        2, 4, 3, 4, 4, 3, 4, 0, 1, 4, 2, 2, 3, 3, 4, 1, 0, 4, 4, 0, 4, 1,
#        2, 0, 3, 4, 4, 0, 4, 1, 0, 3, 4, 2, 1, 0, 0, 3, 2, 1, 1, 1, 4, 1,
#        0, 2, 3, 4, 3, 2, 2, 1, 3, 0, 1, 2, 0, 0, 1, 2, 0, 4, 3, 1, 0, 1,
#        1, 2], dtype=int32)

# %%
plt.Figure(figsize=(5,5))
plt.scatter(data[:, 0], data[:, 1], color='black', s=10)
plt.show()

# %%
# Visualize the 5 clusters
plt.figure(figsize=(5,5))
plt.scatter(data[:, 0], data[:, 1], color="black", s=10)
plt.scatter(model.cluster_centers_[:, 0], model.cluster_centers_[:, 1], color="red", s=30)

step = 0.01
x_min, x_max = data[:, 0].min() - 1, data[:, 0].max() + 1
y_min, y_max = data[:, 1].min() - 1, data[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, step), np.arange(y_min, y_max, step))
Z = model.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)
plt.contourf(xx, yy, Z, alpha=0.4)

plt.show()

# %% [markdown]
# ex 2

# %%
df1 = pd.read_csv("data_9_2.csv")

# %%
df1
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001003    Male     Yes          1      Graduate            No
# 1    LP001005    Male     Yes          0      Graduate           Yes
# 2    LP001006    Male     Yes          0  Not Graduate            No
# 3    LP001008    Male      No          0      Graduate            No
# 4    LP001013    Male     Yes          0  Not Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 376  LP002953    Male     Yes         3+      Graduate            No
# 377  LP002974    Male     Yes          0      Graduate            No
# 378  LP002978  Female      No          0      Graduate            No
# 379  LP002979    Male     Yes         3+      Graduate            No
# 380  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...
